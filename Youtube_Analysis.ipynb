# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyCCLhki4bVMfByLo0CsscBHV1PZGSeTdXw'

youtube = build('youtube', 'v3', developerKey=api_key)  # Corrected 'developerKey'

request = youtube.channels().list(
        part='statistics',
        forHandle='IkoNini'
)

response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'NKUh0AbMKVU9U4JxRftMlNJCDkQ', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'JVHsM5zEt0qA6upQt4XF2zdjFI0', 'id': 'UC5h4-WH0LAV4CWs380yM33A', 'statistics': {'viewCount': '27783908', 'subscriberCount': '126000', 'hiddenSubscriberCount': False, 'videoCount': '2436'}}]}

# %%
import pandas as pd
from googleapiclient.discovery import build
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the YouTube API client
api_key = 'AIzaSyCCLhki4bVMfByLo0CsscBHV1PZGSeTdXw'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, **kwargs):
    request = youtube.channels().list(**kwargs)
    response = request.execute()
    return response

def get_popular_channels_in_kenya(youtube, regionCode='KE', maxResults=10):
    request = youtube.search().list(
        part='snippet',
        regionCode=regionCode,
        type='channel',
        maxResults=maxResults
    )
    response = request.execute()
    return response

# Fetch popular channels in Kenya
popular_channels = get_popular_channels_in_kenya(youtube, maxResults=50)

channel_data = []
for item in popular_channels['items']:
    channel_id = item['snippet']['channelId']
    channel_title = item['snippet']['title']
    channel_stats = get_channel_stats(youtube, part='statistics', id=channel_id)
    
    for stats in channel_stats['items']:
        data = {
            'channel_id': channel_id,
            'channel_title': channel_title,
            'subscriber_count': int(stats['statistics'].get('subscriberCount', 0)),
            'view_count': int(stats['statistics'].get('viewCount', 0)),
            'video_count': int(stats['statistics'].get('videoCount', 0))
        }
        channel_data.append(data)

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Basic data analysis
print(df.describe())

# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x='subscriber_count', y='channel_title', data=df.sort_values(by='subscriber_count', ascending=False))
plt.xlabel('Subscriber Count')
plt.ylabel('Channel')
plt.title('Top YouTube Channels in Kenya by Subscriber Count')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='view_count', y='channel_title', data=df.sort_values(by='view_count', ascending=False))
plt.xlabel('View Count')
plt.ylabel('Channel')
plt.title('Top YouTube Channels in Kenya by View Count')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='video_count', y='channel_title', data=df.sort_values(by='video_count', ascending=False))
plt.xlabel('Video Count')
plt.ylabel('Channel')
plt.title('Top YouTube Channels in Kenya by Video Count')
plt.show()
# Out:
#        subscriber_count     view_count  video_count
# count         50.000000      50.000000    50.000000
# mean         122.300000    6040.440000    12.240000
# std          331.614126   19128.504996    22.553845
# min            0.000000       0.000000     0.000000
# 25%            4.250000     119.500000     4.000000
# 50%           17.000000     712.000000     6.000000
# 75%           83.250000    2706.750000     9.750000
# max         1750.000000  124327.000000   124.000000

# %%
import pandas as pd
from googleapiclient.discovery import build

# Set up the YouTube API client
api_key = 'AIzaSyCCLhki4bVMfByLo0CsscBHV1PZGSeTdXw'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, **kwargs):
    request = youtube.channels().list(**kwargs)
    response = request.execute()
    return response

def get_popular_channels_in_kenya(youtube, regionCode='KE', maxResults=50):
    request = youtube.search().list(
        part='snippet',
        regionCode=regionCode,
        type='channel',
        maxResults=maxResults
    )
    response = request.execute()
    return response

# Fetch popular channels in Kenya
popular_channels = get_popular_channels_in_kenya(youtube, maxResults=50)

channel_data = []
for item in popular_channels['items']:
    channel_id = item['snippet']['channelId']
    channel_title = item['snippet']['title']
    channel_stats = get_channel_stats(youtube, part='statistics', id=channel_id)
    
    for stats in channel_stats['items']:
        data = {
            'channel_id': channel_id,
            'channel_title': channel_title,
            'subscriber_count': int(stats['statistics'].get('subscriberCount', 0)),
            'view_count': int(stats['statistics'].get('viewCount', 0)),
            'video_count': int(stats['statistics'].get('videoCount', 0))
        }
        channel_data.append(data)

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Sort and list the top 20 channels by subscriber count, view count, and video count
top_20_subscribers = df.sort_values(by='subscriber_count', ascending=False).head(20)
top_20_views = df.sort_values(by='view_count', ascending=False).head(20)
top_20_videos = df.sort_values(by='video_count', ascending=False).head(20)

# Print the lists
print("Top 20 YouTube Channels in Kenya by Subscriber Count:")
print(top_20_subscribers[['channel_title', 'subscriber_count']].to_string(index=False))

print("\nTop 20 YouTube Channels in Kenya by View Count:")
print(top_20_views[['channel_title', 'view_count']].to_string(index=False))

print("\nTop 20 YouTube Channels in Kenya by Video Count:")
print(top_20_videos[['channel_title', 'video_count']].to_string(index=False))
# Out:
# Top 20 YouTube Channels in Kenya by Subscriber Count:
#                              channel_title  subscriber_count
#                        Aroji Chogo - Topic              1750
#                    MAXWELL MWALIMU - Topic              1570
#                      dancelo musiq - Topic               417
#                           Dj Tunzy - Topic               376
#                        Tony kajohn - Topic               349
#                      RUMUS SIDNEY 2 DIGIT                241
#                  Wrong Turn Family - Topic               158
#                   Shiqo nya Kisumu - Topic               115
#                              Jack cadnaan                115
# Dominion Voices Ministers - Kisumu - Topic               109
#          Solemn Friends Ministers -Nairobi                98
#                       Tezrah Malia - Topic                89
#                    Polaris Pauline - Topic                85
#                             S.O.S. - Topic                78
#                        Luddy Meryl - Topic                64
#                         Fabrice TG - Topic                61
#                            ceezlah - Topic                53
#                           Kuldeep Kumar-mi                46
#                     CAPO TO DI TOP - Topic                37
#                         Ykey Kenya - Topic                33
#
# Top 20 YouTube Channels in Kenya by View Count:
#                              channel_title  view_count
#                        Aroji Chogo - Topic      124327
#                           Dj Tunzy - Topic       44831
#                    MAXWELL MWALIMU - Topic       30661
#                      dancelo musiq - Topic       30609
#                        Tony kajohn - Topic       13645
#                           D'jungle - Topic        6385
#                           Kuldeep Kumar-mi        6218
#                      RUMUS SIDNEY 2 DIGIT         5722
#          Solemn Friends Ministers -Nairobi        5352
#                            ceezlah - Topic        4422
#                    Polaris Pauline - Topic        4390
#            AIC Mulango Joint Choir - Topic        3628
#                  Wrong Turn Family - Topic        2741
# Dominion Voices Ministers - Kisumu - Topic        2604
#                        Luddy Meryl - Topic        1648
#                     CAPO TO DI TOP - Topic        1473
#                   Shiqo nya Kisumu - Topic        1426
#                          Komanda X - Topic        1295
#                       Young Gideon - Topic        1227
#                       Tezrah Malia - Topic        1023
#
# Top 20 YouTube Channels in Kenya by Video Count:
#                              channel_title  video_count
#                       Young Gideon - Topic          124
#            AIC Mulango Joint Choir - Topic          101
# Dominion Voices Ministers - Kisumu - Topic           57
#                           Dj Tunzy - Topic           26
#                     CAPO TO DI TOP - Topic           22
#                      dancelo musiq - Topic           19
#                   ZOMBIE MUSIC ENT - Topic           16
#                           D'jungle - Topic           12
#                         ALI ROBERT - Topic           11
#                         Fabrice TG - Topic           10
#                        Aroji Chogo - Topic           10
#                             S.O.S. - Topic           10
#                  The Chronicles ZM - Topic           10
#                            ZIWANNY - Topic            9
#                         Ykey Kenya - Topic            9
#                              Jack cadnaan             9
#                  Wrong Turn Family - Topic            9
#                          Komanda X - Topic            8
#                            ceezlah - Topic            8
#                              Sklye - Topic            8

# %%
import pandas as pd
from googleapiclient.discovery import build

# Set up the YouTube API client
api_key = 'AIzaSyCCLhki4bVMfByLo0CsscBHV1PZGSeTdXw'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, **kwargs):
    request = youtube.channels().list(**kwargs)
    response = request.execute()
    return response

def search_channels_by_keyword(youtube, query, regionCode='KE', maxResults=50):
    request = youtube.search().list(
        part='snippet',
        q=query,
        regionCode=regionCode,
        type='channel',
        maxResults=maxResults
    )
    response = request.execute()
    return response

# Search for channels related to Kenya
search_query = "Top Channels in Kenya"
search_results = search_channels_by_keyword(youtube, query=search_query, maxResults=50)

channel_data = []
for item in search_results['items']:
    channel_id = item['snippet']['channelId']
    channel_title = item['snippet']['title']
    channel_stats = get_channel_stats(youtube, part='statistics', id=channel_id)
    
    for stats in channel_stats['items']:
        data = {
            'channel_id': channel_id,
            'channel_title': channel_title,
            'subscriber_count': int(stats['statistics'].get('subscriberCount', 0)),
            'view_count': int(stats['statistics'].get('viewCount', 0)),
            'video_count': int(stats['statistics'].get('videoCount', 0))
        }
        channel_data.append(data)

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Sort and list the top 20 channels by subscriber count, view count, and video count
top_20_subscribers = df.sort_values(by='subscriber_count', ascending=False).head(20)
top_20_views = df.sort_values(by='view_count', ascending=False).head(20)
top_20_videos = df.sort_values(by='video_count', ascending=False).head(20)

# Print the lists
print("Top 20 YouTube Channels related to Kenya by Subscriber Count:")
print(top_20_subscribers[['channel_title', 'subscriber_count']].to_string(index=False))

print("\nTop 20 YouTube Channels related to Kenya by View Count:")
print(top_20_views[['channel_title', 'view_count']].to_string(index=False))

print("\nTop 20 YouTube Channels related to Kenya by Video Count:")
print(top_20_videos[['channel_title', 'video_count']].to_string(index=False))
# Out:
# Top 20 YouTube Channels related to Kenya by Subscriber Count:
#              channel_title  subscriber_count
# Best Ever Food Review Show          10800000
#                 Kanye West          10800000
#                 Mark Wiens          10700000
#                 Beta Squad           9950000
#               RealLifeLore           7520000
#       Architectural Digest           6770000
#           Citizen TV Kenya           5070000
#            TopNotch Idiots           4140000
#          bald and bankrupt           4120000
#                   Kurt Caz           3060000
#          FRANCE 24 English           3010000
#         Dhruv Rathee Vlogs           2980000
#            NHK WORLD-JAPAN           2880000
#             KTN News Kenya           2850000
#              BBC News اردو           2830000
#                  SABC News           2490000
#              Naa Anveshana           2100000
#               Kanel Joseph           2050000
#         Passenger Paramvir           1730000
#            Arun Surya Teja           1720000
#
# Top 20 YouTube Channels related to Kenya by View Count:
#              channel_title  view_count
#                 Kanye West  7524390051
#                 Mark Wiens  2704103871
# Best Ever Food Review Show  2673528770
#           Citizen TV Kenya  2063095951
#               RealLifeLore  1652660296
#       Architectural Digest  1389895869
#                 Beta Squad  1356299378
#                  SABC News  1301852855
#          FRANCE 24 English  1213488672
#                   Kurt Caz  1012389242
#             KTN News Kenya   798843169
#            TopNotch Idiots   683505568
#          bald and bankrupt   658180129
#            NHK WORLD-JAPAN   654138482
#              BBC News اردو   577664468
#              Naa Anveshana   549891979
#     Baseball Doesn't Exist   538818854
#         Dhruv Rathee Vlogs   480356773
#              Harry Jaggard   406566470
#         Passenger Paramvir   312921540
#
# Top 20 YouTube Channels related to Kenya by Video Count:
#                        channel_title  video_count
#                            SABC News       224236
#                     Citizen TV Kenya       175127
#                       KTN News Kenya       148116
#                    FRANCE 24 English       100930
#                            Inooro TV        52823
#                           africanews        29363
#                        BBC News اردو         9711
#                     Asad Yaqub IELTS         6727
#                      NHK WORLD-JAPAN         1806
#                           Mark Wiens         1424
#                  The Running Channel         1239
#                        Naa Anveshana         1094
#                 Architectural Digest          908
#                             Kurt Caz          817
# Learn Swahili with SwahiliPod101.com          739
#           Best Ever Food Review Show          696
#                        Zaki Saudagar          547
#             the Luxury Travel Expert          540
#                  BK Trading Academy           491
#                           Abel Mutua          432

# %%
import pandas as pd
from googleapiclient.discovery import build

# Set up the YouTube API client
api_key = 'AIzaSyCCLhki4bVMfByLo0CsscBHV1PZGSeTdXw'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, **kwargs):
    request = youtube.channels().list(**kwargs)
    response = request.execute()
    return response

def search_channels_by_keyword(youtube, query, regionCode='KE', location='KE', videoCategoryId='24', chart='mostPopular', maxResults=50):
    request = youtube.search().list(
        part='snippet',
        q=query,
        regionCode=regionCode,
        type='channel',
        maxResults=maxResults
    )
    response = request.execute()
    return response

# Search for channels related to Kenya
search_query = "Kenyan KE"
search_results = search_channels_by_keyword(youtube, query=search_query, maxResults=50)

channel_data = []
for item in search_results['items']:
    channel_id = item['snippet']['channelId']
    channel_title = item['snippet']['title']
    channel_description = item['snippet']['description']
    
    # Additional filtering based on keywords in the title and description
    if 'Kenya' in channel_title or 'Kenya' in channel_description:
        channel_stats = get_channel_stats(youtube, part='statistics', id=channel_id)
        
        for stats in channel_stats['items']:
            data = {
                'channel_id': channel_id,
                'channel_title': channel_title,
                'subscriber_count': int(stats['statistics'].get('subscriberCount', 0)),
                'view_count': int(stats['statistics'].get('viewCount', 0)),
                'video_count': int(stats['statistics'].get('videoCount', 0))
            }
            channel_data.append(data)

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Sort and list the top 20 channels by subscriber count, view count, and video count
top_20_subscribers = df.sort_values(by='subscriber_count', ascending=False).head(20)
top_20_views = df.sort_values(by='view_count', ascending=False).head(20)
top_20_videos = df.sort_values(by='video_count', ascending=False).head(20)

# Print the lists
print("Top 20 YouTube Channels related to Kenya by Subscriber Count:")
print(top_20_subscribers[['channel_title', 'subscriber_count']].to_string(index=False))

print("\nTop 20 YouTube Channels related to Kenya by View Count:")
print(top_20_views[['channel_title', 'view_count']].to_string(index=False))

print("\nTop 20 YouTube Channels related to Kenya by Video Count:")
print(top_20_videos[['channel_title', 'video_count']].to_string(index=False))
# Out:
# Top 20 YouTube Channels related to Kenya by Subscriber Count:
#                  channel_title  subscriber_count
#               Citizen TV Kenya           5070000
#                 KTN News Kenya           2850000
#                      NTV Kenya           2480000
#            Tuko / Tuco - Kenya           1070000
#                  KBC Channel 1            440000
#               Pulse Live Kenya             82500
#                 The Star Kenya             80300
#              State House Kenya             72200
#                 Nuru Okanga Ke             35500
#                    KE CENTRAL              34300
#                   Edu TV Kenya             33800
#                  Kenyans.co.ke             33400
#                    Carlture KE             28200
#            Forever Young kenya             22600
#                 NTV Kenya Live             20200
#                Rudra Kartel Ke             17200
#                   Ashley Kenya             16800
# KRATV(Kenya Revenue Authority)             12100
#                   HighGrade KE              9290
#                 Viral TV Kenya              2080
#
# Top 20 YouTube Channels related to Kenya by View Count:
#                  channel_title  view_count
#               Citizen TV Kenya  2063095951
#                      NTV Kenya  1017542828
#                 KTN News Kenya   798843169
#            Tuko / Tuco - Kenya   227522514
#                  KBC Channel 1    68982636
#                 The Star Kenya    24294606
#               Pulse Live Kenya    12666921
#              State House Kenya    10491303
#                 Nuru Okanga Ke     4706794
#                  Kenyans.co.ke     3203439
#                    KE CENTRAL      3197445
#                   Edu TV Kenya     2265986
#                    Carlture KE     2123601
#            Forever Young kenya     2045144
#                   Ashley Kenya     1817512
#                 NTV Kenya Live     1665007
# KRATV(Kenya Revenue Authority)     1020254
#                   HighGrade KE      649692
#                Rudra Kartel Ke      506150
#                 Viral TV Kenya      230668
#
# Top 20 YouTube Channels related to Kenya by Video Count:
#                  channel_title  video_count
#               Citizen TV Kenya       175133
#                 KTN News Kenya       148123
#                      NTV Kenya        93742
#                  KBC Channel 1        85435
#                 The Star Kenya        12661
#              State House Kenya         3780
#                  Kenyans.co.ke         2573
#               Pulse Live Kenya         1940
#            Tuko / Tuco - Kenya         1823
#                    KE CENTRAL          1327
#                 Nuru Okanga Ke         1251
#                 NTV Kenya Live         1133
#                   Edu TV Kenya          982
# KRATV(Kenya Revenue Authority)          344
#                   Ashley Kenya          206
#                 Viral TV Kenya          138
#                    Carlture KE          108
#         THE FOOTBALL TRIBE ke.          105
#      Kenyan Republic Official            77
#                Kenya Judiciary           67

# %%
final_df = df.sort_values(by = 'subscriber_count', ascending= False)
display(final_df)
# Out:
#                   channel_id                   channel_title  \
# 2   UChBQgieUidXV1CmDxSdRm3g                Citizen TV Kenya
# 3   UCKVsdeoHExltrWMuK0hOWmg                  KTN News Kenya
# 24  UCqBJ47FjJcl61fmSbcadAVg                       NTV Kenya
# 1   UCl6ICaB9meBcSMQ5Zmr446g             Tuko / Tuco - Kenya
# 6   UCypNjM5hP1qcUqQZe57jNfg                   KBC Channel 1
# 26  UCd27iRLqJh3aozOqzGo1ONw                Pulse Live Kenya
# 22  UC-aT2XsRXmTHxnCeUiMNvTw                  The Star Kenya
# 16  UCuNsouEfEq9Sh6tapfg4uRA               State House Kenya
# 10  UCppRyiSEC_Q9HI_4GOLfKoA                  Nuru Okanga Ke
# 19  UC1XmJPsxSTlbP0YzVyJUjAA                     KE CENTRAL
# 11  UCByj0XrDmb0UDUui63EOnhA                    Edu TV Kenya
# 0   UCHphq9udrisoGYguDx-cKoQ                   Kenyans.co.ke
# 4   UCesqweryWGoVzl5Xu5ObDqg                     Carlture KE
# 18  UCrXGE3V5YCf98da5pi3UxrQ             Forever Young kenya
# 17  UCeD_afIRkvpRVW0AZ62lUSw                  NTV Kenya Live
# 23  UCok_wm9T5o5Y3HvV6swmlpQ                 Rudra Kartel Ke
# 8   UCMHxhUubIVwYGnlStAPlVJA                    Ashley Kenya
# 13  UCAurhiLNO-2Qki0yVE5PJuQ  KRATV(Kenya Revenue Authority)
# 29  UCP-FPD708Hh3LY-A6IVzPJw                    HighGrade KE
# 20  UCYVzH8KmnRlAapVXvsPdMEg                  Viral TV Kenya
# 27  UCsvueRDxFNSqVNa-ANmfhXQ                 Kenya Judiciary
# 21  UCkfstucNfLMS4wsrOe9BIjg                      Oskizzo Ke
# 14  UCo2jJX1CoVnLLy2ZvG9NYeQ                    Chacheeta KE
# 25  UCaCVLITmh_aQueWPnTXJ5Ng                      Brapper KE
# 9   UCoWdRiuU1Z7OdzWA7Grm1Nw          THE FOOTBALL TRIBE ke.
# 5   UCW4YoDlcZf-9hjtbTTRHP0w       Kenyan Republic Official
# 28  UCi5_bpgl7e6Rzih-r1baUtA               Artistic Media Ke
# 7   UCdBj7Nsnvwbu52XakCe5e3A                    Kenyan Musik
# 15  UCMWMDJJ15eEOv7e-Puxdq1w                     PHONEZAE KE
# 12  UChT2RhaSwjaAf9iJb1EjOfA                  Whats Next KE?
#
#     subscriber_count  view_count  video_count
# 2            5070000  2063095951       175133
# 3            2850000   798843169       148123
# 24           2480000  1017542828        93742
# 1            1070000   227522514         1823
# 6             440000    68982636        85435
# 26             82500    12666921         1940
# 22             80300    24294606        12661
# 16             72200    10491303         3780
# 10             35500     4706794         1251
# 19             34300     3197445         1327
# 11             33800     2265986          982
# 0              33400     3203439         2573
# 4              28200     2123601          108
# 18             22600     2045144           24
# 17             20200     1665007         1133
# 23             17200      506150           38
# 8              16800     1817512          206
# 13             12100     1020254          344
# 29              9290      649692           22
# 20              2080      230668          138
# 27              1440       39978           67
# 21              1160        7608           12
# 14              1150       60345           37
# 25              1080       23410            4
# 9                715       25178          105
# 5                295       44403           77
# 28               266       10581           23
# 7                178       36607            4
# 15               122        2134           12
# 12                12         314            2

# %%
#visualization

plt.figure(figsize=(10, 8))
plt.barh(top_20_subscribers['channel_title'], top_20_subscribers['subscriber_count'], color='skyblue')
plt.xlabel('Subscriber Count in Millions')
plt.ylabel('Channel Title')
plt.title('Top 20 YouTube Channels in Kenya by Subscriber Count')
plt.gca().invert_yaxis()
plt.show()

# %%
#visualization

plt.figure(figsize=(10, 8))
plt.barh(top_20_views['channel_title'], top_20_views['view_count'], color='Black')
plt.xlabel('Views in Millions')
plt.ylabel('Channel Title')
plt.title('Top 20 YouTube Channels in Kenya by Views')
plt.gca().invert_yaxis()
plt.show()

# %%
#visualization

plt.figure(figsize=(10, 8))
plt.barh(top_20_videos['channel_title'], top_20_videos['video_count'], color='green')
plt.xlabel('Number of Videos in Thousands')
plt.ylabel('Channel Title')
plt.title('Top 20 YouTube Channels in Kenya by Number of videos')
plt.gca().invert_yaxis()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        30 non-null     object
#  1   channel_title     30 non-null     object
#  2   subscriber_count  30 non-null     int64
#  3   view_count        30 non-null     int64
#  4   video_count       30 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.3+ KB

# %%
import seaborn as sns
numerical_df = df[['subscriber_count','view_count','video_count']]
sns.heatmap(numerical_df.corr(),annot=True)
plt.show()
